# %%
print('Hello World')
# Out:
# Hello World

# %%
name= 'John'
print(name)
# Out:
# John

# %%
intro= name +' '+ 'Beka'
print(intro)
# Out:
# John Beka

# %% [markdown]
# ###### hi

# %% [markdown]
# # HI
# ### HOW ARE YOU

# %%
import matplotlib as mat

# %%
print(name)
# Out:
# John

# %%
print('Hello World')

# %% [markdown]
# # hi why

# %%
name = input('Enter your name here: ')
surname = input('Enter your surname here: ')
age = input('How old are you?: ')
print(name + ' '+ 
     surname + ' '+
     age)
# Out:
# Enter your name here: Alvera
# Enter your surname here: Beka
# How old are you?: 22
# Alvera Beka 22

# %%
coursework_mark = float(input("Enter your coursework mark here: "))
exam_mark = float(input("Enter your exam mark here: "))
total_mark = 30/100 * coursework_mark + 70/100 * exam_mark
print(format(total_mark, ".2f"))
# Out:
# Enter your coursework mark here: 77.50
# Enter your exam mark here: 65.23
# 68.91
